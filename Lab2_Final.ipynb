# %%
#[CELL 1] CONFIGURATION
ENGINEER = "MAÑIBO"
STUDENT_ID = "TUPM-25-5552"

#Derivation: Extract the last digit to act as your Logic Seed
SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: MAÑIBO
# Algorithmic Seed Value: 2

# %%
#[CELL2] ARCHITECTURE TEST
#Logic: Mathematically, 0.1 + 0.2 = 0.3. Does the computer agree?
actual = 0.1 + 0.2

print(f"Python stores: {actual}")

if actual  == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: PRECISION ERROR (Binary Artifact)")
# Out:
# Python stores: 0.30000000000000004
# Result: PRECISION ERROR (Binary Artifact)

# %%
#[CELL3] ASCII INSPECTION
first_letter = ENGINEER[0]
byte_val = ord(first_letter)# Convert Char to Integer Memory Code

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: M
# ASCII Value: 77
# Next in Sequence: N

# %%
#[CELL 4] SANITIZATION
raw_in = input("Mañibo (add messy spaces): ")
# Pipeline: Strip whitespace -> Convert to Uppercase
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned: '{clean_in}'")
# Out:
# Original: '' | Cleaned: ''

# %%
# [CELL 5] DATA EXISTENCE
user_input = input("Press Enter (leave empty) or type data: ")

# Pythonic Way: An empty string is treated as False.
if user_input:
  print(f"Data Detected: {user_input}")
else:
  print("ALERT: No data stream detected.")
# Out:
# ALERT: No data stream detected.

# %%
# [CELL 6] SLICING & PARSING
STUDENT_ID = "TUPC-2023-0001"
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

# Tokenization: Split string into a List based on delimiter
tokens = STUDENT_ID.split("-")

print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPC
# Unique Sequence: 3-0001
# Token List: ['TUPC', '2023', '0001']

# %%
#[CELL 7] MODULO OPERATOR
#Logic: Check if Seed Number is even or Odd using %
SEED_NUM = 123  # Example seed number
if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: HIGH (Odd Seed)

# %%
# [CELL 8] DYNAMIC LIMITS
# The limit changes for every student
limit = (SEED_NUM * 10) + 20
print(f"--- SAFETY LIMIT: {limit} ---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over Limit")
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# --- SAFETY LIMIT: 1020 ---
# STATUS: Nominal

# %%
# [CELL 9] ROBUST INPUT (Exception Handling)
try:
  # Attempt to convert input to integer
  voltage = int(input("Enter Voltage (Numeric): "))
  print(f"Voltage Captured: {voltage}V")
except ValueError:
  # This block runs ONLY if the user types text (e.g., "Five")
  # instead of a number. Resetting to 0.
  print("SYSTEM ERROR: Input must be numeric. Resetting to 0.")
  voltage = 0

print(f"System continues... Current Voltage: {voltage}")
# Out:
# Voltage Captured: 1020V
# System continues... Current Voltage: 1020

# %%
# [CELL 10] LOGIC GATES
has_power = False

# Python sees False and STOPS checking. It never runs the second part.
if has_power and (10 / 0 == 0):
  print("System On")
else:
  print("System Off (Short-Circuit Triggered)")
# Out:
# System Off (Short-Circuit Triggered)

# %%
# [CELL 11] FOR LOOP
SEED_NUM = 100 # Assuming a SEED_NUM for demonstration purposes
loops = SEED_NUM + 3
print(f"---- RUNNING {loops} CYCLES ----")

for i in range(1, loops + 1):
  print(f"Cycle {i}/{loops} ... Complete")
# Out:
# ---- RUNNING 103 CYCLES ----
# Cycle 1/103 ... Complete
# Cycle 2/103 ... Complete
# Cycle 3/103 ... Complete
# Cycle 4/103 ... Complete
# Cycle 5/103 ... Complete
# Cycle 6/103 ... Complete
# Cycle 7/103 ... Complete
# Cycle 8/103 ... Complete
# Cycle 9/103 ... Complete
# Cycle 10/103 ... Complete
# Cycle 11/103 ... Complete
# Cycle 12/103 ... Complete
# Cycle 13/103 ... Complete
# Cycle 14/103 ... Complete
# Cycle 15/103 ... Complete
# Cycle 16/103 ... Complete
# Cycle 17/103 ... Complete
# Cycle 18/103 ... Complete
# Cycle 19/103 ... Complete
# Cycle 20/103 ... Complete
# Cycle 21/103 ... Complete
# Cycle 22/103 ... Complete
# Cycle 23/103 ... Complete
# Cycle 24/103 ... Complete
# Cycle 25/103 ... Complete
# Cycle 26/103 ... Complete
# Cycle 27/103 ... Complete
# Cycle 28/103 ... Complete
# Cycle 29/103 ... Complete
# Cycle 30/103 ... Complete
# Cycle 31/103 ... Complete
# Cycle 32/103 ... Complete
# Cycle 33/103 ... Complete
# Cycle 34/103 ... Complete
# Cycle 35/103 ... Complete
# Cycle 36/103 ... Complete
# Cycle 37/103 ... Complete
# Cycle 38/103 ... Complete
# Cycle 39/103 ... Complete
# Cycle 40/103 ... Complete
# Cycle 41/103 ... Complete
# Cycle 42/103 ... Complete
# Cycle 43/103 ... Complete
# Cycle 44/103 ... Complete
# Cycle 45/103 ... Complete
# Cycle 46/103 ... Complete
# Cycle 47/103 ... Complete
# Cycle 48/103 ... Complete
# Cycle 49/103 ... Complete
# Cycle 50/103 ... Complete
# Cycle 51/103 ... Complete
# Cycle 52/103 ... Complete
# Cycle 53/103 ... Complete
# Cycle 54/103 ... Complete
# Cycle 55/103 ... Complete
# Cycle 56/103 ... Complete
# Cycle 57/103 ... Complete
# Cycle 58/103 ... Complete
# Cycle 59/103 ... Complete
# Cycle 60/103 ... Complete
# Cycle 61/103 ... Complete
# Cycle 62/103 ... Complete
# Cycle 63/103 ... Complete
# Cycle 64/103 ... Complete
# Cycle 65/103 ... Complete
# Cycle 66/103 ... Complete
# Cycle 67/103 ... Complete
# Cycle 68/103 ... Complete
# Cycle 69/103 ... Complete
# Cycle 70/103 ... Complete
# Cycle 71/103 ... Complete
# Cycle 72/103 ... Complete
# Cycle 73/103 ... Complete
# Cycle 74/103 ... Complete
# Cycle 75/103 ... Complete
# Cycle 76/103 ... Complete
# Cycle 77/103 ... Complete
# Cycle 78/103 ... Complete
# Cycle 79/103 ... Complete
# Cycle 80/103 ... Complete
# Cycle 81/103 ... Complete
# Cycle 82/103 ... Complete
# Cycle 83/103 ... Complete
# Cycle 84/103 ... Complete
# Cycle 85/103 ... Complete
# Cycle 86/103 ... Complete
# Cycle 87/103 ... Complete
# Cycle 88/103 ... Complete
# Cycle 89/103 ... Complete
# Cycle 90/103 ... Complete
# Cycle 91/103 ... Complete
# Cycle 92/103 ... Complete
# Cycle 93/103 ... Complete
# Cycle 94/103 ... Complete
# Cycle 95/103 ... Complete
# Cycle 96/103 ... Complete
# Cycle 97/103 ... Complete
# Cycle 98/103 ... Complete
# Cycle 99/103 ... Complete
# Cycle 100/103 ... Complete
# Cycle 101/103 ... Complete
# Cycle 102/103 ... Complete
# Cycle 103/103 ... Complete

# %%
# [CELL 12] NESTED LOOPS
STUDENT_ID = "TUPC-2023-0001" # Example student ID
tokens = STUDENT_ID.split("-")

# First digit of unique ID determines Rows
rows = int(tokens[2][0])
# Last digit of unique ID determines Columns
cols = int(tokens[2][-1])

print(f"Generating {rows}x{cols} Matrix:")

for r in range(rows):
  for c in range(cols):
    print("#", end=" ")# Print on the same line
  print()
# Out:
# Generating 0x1 Matrix:

# %%
# [CELL 13] INPUT VALIDATION
while True:
  pwd = input("Type 'ADMIN' to exit: ")
  if pwd == "ADMIN":
    print("Unlocked.")
    break # Break terminates the infinite loop
  else:
    print("Access Denied.")
# Out:
# Unlocked.

# %%
# [CELL 14] FORENSIC HASH CALCULATION
# A = ASCII Value of first letter (Calculated in Task 5)
byte_val = ord('E') # Assuming 'E' from "ENGINEER" as an example for Task 5

# B = Seed Number (Calculated in Task 3)
SEED_NUM = 123 # Example seed number from Task 3

# C = Total Loop Cycles (Calculated in Task 14)
loops = SEED_NUM + 3 # Example loops from Task 14

# Formula: (ASCII * Seed) - Loops
verification_hash = (byte_val * SEED_NUM) - loops

print(f"User: ENGINEER")
print(f"Forensic Signature: {verification_hash}")
# Out:
# User: ENGINEER
# Forensic Signature: 8361
